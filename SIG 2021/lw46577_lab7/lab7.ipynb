# %%
import os
import fiona
import numpy as np
import pprint
import matplotlib.pyplot as plt
import geopandas as gpd
import pandas as pd
import json

# %%
path=r"C:\Users\JaSzw\OneDrive\Pulpit\Geoinfa\3262_GML\PL.PZGiK.339.3262\BDOT10k" 
file="PL.PZGiK.339.3262__OT_BUBD_A.xml"
bud=os.path.join(path,file)
bud_gdf = gpd.read_file(bud)
bud_gdf.head()
# Out:
#                                            gml_id  \
# 0  OT_BUBD_A.e3ef7bab-1ff8-4f4f-971f-a304a8c7f9f0
# 1  OT_BUBD_A.aa8b7fe4-1c3a-4192-88e3-9fa9bbac8212
# 2  OT_BUBD_A.ed79aed8-bbc9-4eab-a40d-8024f31593d1
# 3                                  OT_BUBD_A.9479
# 4                                  OT_BUBD_A.4402
#
#                               lokalnyId        przestrzenNazw  \
# 0  0dca70f9-c149-49cb-bbac-f3e6abed789b  PL.PZGiK.339.BDOT10k
# 1  d1bd024e-3811-4222-91df-d08b6a8c43e0  PL.PZGiK.339.BDOT10k
# 2  88d77d4a-64f8-4849-86fd-f955fedd9894  PL.PZGiK.339.BDOT10k
# 3  2DDDABF6-B518-0D26-E053-CC2BA8C04634  PL.PZGiK.339.BDOT10k
# 4  2DDDABF6-A20B-0D26-E053-CC2BA8C04634  PL.PZGiK.339.BDOT10k
#
#               wersjaId  czyObiektBDOO   x_kod x_skrKarto x_katDoklGeom  \
# 0  2019-08-15T00:00:00          False  BUBD11       None           Dok
# 1  2019-08-15T00:00:00          False  BUBD11       None           Dok
# 2  2019-08-15T00:00:00          False  BUBD12       mag.           Dok
# 3  2019-08-15T00:00:00          False  BUBD18       None           Dok
# 4  2019-08-15T00:00:00          False  BUBD01       None           Dok
#
#   x_zrodloDanychG x_zrodloDanychA  ... x_kodKarto250k x_kodKarto500k  \
# 0            EGiB             Trn  ...           None           None
# 1            EGiB             Trn  ...           None           None
# 2            EGiB             Trn  ...           None           None
# 3            EGiB             Trn  ...           None           None
# 4            EGiB             Trn  ...           None           None
#
#   x_kodKarto1000k funOgolnaBudynku liczbaKondygnacji kodKst zabytek  \
# 0            None             1251               1.0    101   False
# 1            None             1251               1.0    101   False
# 2            None             1252               1.0    104   False
# 3            None             1271               1.0    108   False
# 4            None             1110               1.0    110   False
#
#   x_informDodatkowa nazwa                                           geometry
# 0              None  None  POLYGON ((212796.620 622288.740, 212791.440 62...
# 1              None  None  POLYGON ((213200.300 622387.300, 213154.070 62...
# 2              None  None  POLYGON ((212755.560 622393.420, 212781.130 62...
# 3              None  None  POLYGON ((201243.840 630100.150, 201249.190 63...
# 4              None  None  POLYGON ((200128.040 625602.910, 200127.770 62...
#
# [5 rows x 30 columns]

# %%
bud_gdf.plot()
# Out:
# <AxesSubplot:>

# %%
bud_gdf.crs
# Out:
# <Projected CRS: EPSG:2180>
# Name: ETRS89 / Poland CS92
# Axis Info [cartesian]:
# - x[north]: Northing (metre)
# - y[east]: Easting (metre)
# Area of Use:
# - name: Poland
# - bounds: (14.14, 49.0, 24.15, 55.93)
# Coordinate Operation:
# - name: Poland CS92
# - method: Transverse Mercator
# Datum: European Terrestrial Reference System 1989
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
bud_gdf_gj=bud_gdf.to_crs("EPSG:4326")
bud_gdf_gj.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
bud_gdf_sh=bud_gdf.to_crs("EPSG:3857")
bud_gdf_geopack=bud_gdf.to_crs("EPSG:32633")
bud_gdf_gml=bud_gdf.to_crs("EPSG:2176")
bud_gdf_gj.to_file('C:\\Users\JaSzw\OneDrive\Pulpit\Geoinfa\Wynik_1.geojson', driver='GeoJSON')
bud_gdf_sh.to_file('C:\\Users\JaSzw\OneDrive\Pulpit\Geoinfa\Wynik_1.shp', driver='ESRI Shapefile')
bud_gdf_geopack.to_file('C:\\Users\JaSzw\OneDrive\Pulpit\Geoinfa\Wynik_1.gpkg', driver='GPKG')
bud_gdf_gml.to_file('C:\\Users\JaSzw\OneDrive\Pulpit\Geoinfa\Wynik_1.gml', driver='GML')

# %%
path=r"C:\Users\JaSzw\OneDrive\Pulpit\Geoinfa\3262_GML\PL.PZGiK.339.3262\BDOT10k" 
file6="SpecjalneObszaryOchronyPolygon.shp"
file7="powiaty.gpkg"
nat=os.path.join(path,file6)
powiaty=os.path.join(path,file7)
polygon = gpd.read_file(powiaty)
nat_gdf = gpd.read_file(nat)
nat_gdf.head()
# Out:
#      gid                    nazwa        kod                     kodinspire  \
# 0  45091                Horodysko  PLH060060  PL.ZIPOP.1393.N2K.PLH060060.H
# 1  44940           Dolina £êtowni  PLH060040  PL.ZIPOP.1393.N2K.PLH060040.H
# 2  45348  Kampinoska Dolina Wis³y  PLH140029  PL.ZIPOP.1393.N2K.PLH140029.H
# 3  44690              Bia³e B³oto  PLH220002  PL.ZIPOP.1393.N2K.PLH220002.H
# 4  45373                   Hopowo  PLH220010  PL.ZIPOP.1393.N2K.PLH220010.H
#
#                                             geometry
# 0  POLYGON ((810055.592 337679.124, 810037.176 33...
# 1  MULTIPOLYGON (((780309.288 334456.208, 780299....
# 2  MULTIPOLYGON (((550908.579 511298.941, 550975....
# 3  POLYGON ((427975.754 736024.259, 428095.827 73...
# 4  POLYGON ((450700.232 711512.218, 450619.731 71...

# %%
polygon.head()
# Out:
#      iip_przest                            iip_identy  \
# 0  PL.PZGIK.200  f87cae01-4621-41f4-b768-c777cf94d1d8
# 1  PL.PZGIK.200  f322275e-1c48-431f-889e-8bb0ccb46e81
# 2  PL.PZGIK.200  59e7c5a7-8597-4c55-812a-b30932c08dd2
# 3  PL.PZGIK.200  e86b1e71-8958-42ee-bec5-ca3c87907bc8
# 4  PL.PZGIK.200  7f2af54d-150f-4b9f-b9fb-d2ce1b04166e
#
#                   iip_wersja jpt_sjr_ko jpt_kod_je  \
# 0  2012-09-27T08:01:01+02:00        POW       1812
# 1  2012-09-27T08:01:01+02:00        POW       1813
# 2  2012-09-27T08:01:01+02:00        POW       1814
# 3  2012-09-27T08:01:01+02:00        POW       1815
# 4  2012-09-27T08:01:01+02:00        POW       1816
#
#                       jpt_nazwa_ jpt_nazw01 jpt_organ_ jpt_orga01  jpt_jor_id  \
# 0                powiat niżański       None       None        NZN         NaN
# 1               powiat przemyski       None       None        NZN         NaN
# 2              powiat przeworski       None       None        NZN         NaN
# 3  powiat ropczycko-sędziszowski       None       None        NZN         NaN
# 4              powiat rzeszowski       None       None        NZN         NaN
#
#    ... id_bufora_ id_bufor01 id_technic jpt_opis jpt_sps_ko  gra_ids  \
# 0  ...        NaN    13878.0        NaN   829081        UZG     None
# 1  ...        NaN    13878.0        NaN   829082        UZG     None
# 2  ...        NaN    13878.0        NaN   829083        UZG     None
# 3  ...        NaN    13878.0        NaN   829084        UZG     None
# 4  ...        NaN    13878.0        NaN   829085        UZG     None
#
#   status_obi opis_bledu typ_bledu  \
# 0   AKTUALNY       None      None
# 1   AKTUALNY       None      None
# 2   AKTUALNY       None      None
# 3   AKTUALNY       None      None
# 4   AKTUALNY       None      None
#
#                                             geometry
# 0  MULTIPOLYGON (((711095.856 277431.597, 711101....
# 1  MULTIPOLYGON (((734488.435 209795.384, 734490....
# 2  MULTIPOLYGON (((731943.256 233158.050, 731989....
# 3  MULTIPOLYGON (((676562.888 239118.997, 676567....
# 4  MULTIPOLYGON (((696894.808 237348.347, 696909....
#
# [5 rows x 30 columns]

# %%
nat_gdf.plot()
# Out:
# <AxesSubplot:>

# %%
polygon.plot()
# Out:
# <AxesSubplot:>

# %%
powiaty_int = gpd.overlay(nat_gdf, polygon, how='intersection').to_crs("epsg:2180")
powiaty_int.plot()
# Out:
# <AxesSubplot:>

# %%
powiaty_int.head()
# Out:
#      gid                   nazwa        kod                     kodinspire  \
# 0  45091               Horodysko  PLH060060  PL.ZIPOP.1393.N2K.PLH060060.H
# 1  44940          Dolina £êtowni  PLH060040  PL.ZIPOP.1393.N2K.PLH060040.H
# 2  44804                   Debry  PLH060003  PL.ZIPOP.1393.N2K.PLH060003.H
# 3  44828        Dolina Sieniochy  PLH060025  PL.ZIPOP.1393.N2K.PLH060025.H
# 4  44924  Dolina Górnej Siniochy  PLH060086  PL.ZIPOP.1393.N2K.PLH060086.H
#
#      iip_przest                            iip_identy  \
# 0  PL.PZGIK.200  e9e0d8ab-d763-4030-96d5-d82dcb2f09fa
# 1  PL.PZGIK.200  e9e0d8ab-d763-4030-96d5-d82dcb2f09fa
# 2  PL.PZGIK.200  e9e0d8ab-d763-4030-96d5-d82dcb2f09fa
# 3  PL.PZGIK.200  e9e0d8ab-d763-4030-96d5-d82dcb2f09fa
# 4  PL.PZGIK.200  e9e0d8ab-d763-4030-96d5-d82dcb2f09fa
#
#                   iip_wersja jpt_sjr_ko jpt_kod_je       jpt_nazwa_  ...  \
# 0  2012-09-27T07:39:43+02:00        POW       0620  powiat zamojski  ...
# 1  2012-09-27T07:39:43+02:00        POW       0620  powiat zamojski  ...
# 2  2012-09-27T07:39:43+02:00        POW       0620  powiat zamojski  ...
# 3  2012-09-27T07:39:43+02:00        POW       0620  powiat zamojski  ...
# 4  2012-09-27T07:39:43+02:00        POW       0620  powiat zamojski  ...
#
#   id_bufora_ id_bufor01 id_technic  jpt_opis jpt_sps_ko gra_ids status_obi  \
# 0        NaN    13874.0        NaN    829006        UZG    None   AKTUALNY
# 1        NaN    13874.0        NaN    829006        UZG    None   AKTUALNY
# 2        NaN    13874.0        NaN    829006        UZG    None   AKTUALNY
# 3        NaN    13874.0        NaN    829006        UZG    None   AKTUALNY
# 4        NaN    13874.0        NaN    829006        UZG    None   AKTUALNY
#
#   opis_bledu typ_bledu                                           geometry
# 0       None      None  POLYGON ((810055.592 337679.124, 810037.176 33...
# 1       None      None  MULTIPOLYGON (((775061.768 334199.044, 775062....
# 2       None      None  POLYGON ((790918.760 306179.210, 790812.470 30...
# 3       None      None  MULTIPOLYGON (((821338.676 321260.554, 821540....
# 4       None      None  POLYGON ((817086.510 327536.644, 817089.980 32...
#
# [5 rows x 34 columns]

# %%
d = {'iip_identy': powiaty_int['iip_identy'], 'rozmiar_nat': powiaty_int.area/1000000}

# %%
df = pd.DataFrame(data=d)

# %%
nowe=df.groupby(['iip_identy']).sum()

# %%
join = polygon.merge(nowe, on=('iip_identy'),how='left')
join.head()
# Out:
#      iip_przest                            iip_identy  \
# 0  PL.PZGIK.200  f87cae01-4621-41f4-b768-c777cf94d1d8
# 1  PL.PZGIK.200  f322275e-1c48-431f-889e-8bb0ccb46e81
# 2  PL.PZGIK.200  59e7c5a7-8597-4c55-812a-b30932c08dd2
# 3  PL.PZGIK.200  e86b1e71-8958-42ee-bec5-ca3c87907bc8
# 4  PL.PZGIK.200  7f2af54d-150f-4b9f-b9fb-d2ce1b04166e
#
#                   iip_wersja jpt_sjr_ko jpt_kod_je  \
# 0  2012-09-27T08:01:01+02:00        POW       1812
# 1  2012-09-27T08:01:01+02:00        POW       1813
# 2  2012-09-27T08:01:01+02:00        POW       1814
# 3  2012-09-27T08:01:01+02:00        POW       1815
# 4  2012-09-27T08:01:01+02:00        POW       1816
#
#                       jpt_nazwa_ jpt_nazw01 jpt_organ_ jpt_orga01  jpt_jor_id  \
# 0                powiat niżański       None       None        NZN         NaN
# 1               powiat przemyski       None       None        NZN         NaN
# 2              powiat przeworski       None       None        NZN         NaN
# 3  powiat ropczycko-sędziszowski       None       None        NZN         NaN
# 4              powiat rzeszowski       None       None        NZN         NaN
#
#    ... id_bufor01 id_technic jpt_opis jpt_sps_ko gra_ids  status_obi  \
# 0  ...    13878.0        NaN   829081        UZG    None    AKTUALNY
# 1  ...    13878.0        NaN   829082        UZG    None    AKTUALNY
# 2  ...    13878.0        NaN   829083        UZG    None    AKTUALNY
# 3  ...    13878.0        NaN   829084        UZG    None    AKTUALNY
# 4  ...    13878.0        NaN   829085        UZG    None    AKTUALNY
#
#   opis_bledu typ_bledu                                           geometry  \
# 0       None      None  MULTIPOLYGON (((711095.856 277431.597, 711101....
# 1       None      None  MULTIPOLYGON (((734488.435 209795.384, 734490....
# 2       None      None  MULTIPOLYGON (((731943.256 233158.050, 731989....
# 3       None      None  MULTIPOLYGON (((676562.888 239118.997, 676567....
# 4       None      None  MULTIPOLYGON (((696894.808 237348.347, 696909....
#
#   rozmiar_nat
# 0   79.247132
# 1  400.169741
# 2   59.587417
# 3    0.680983
# 4   13.241718
#
# [5 rows x 31 columns]

# %%
join
# Out:
#        iip_przest                            iip_identy  \
# 0    PL.PZGIK.200  f87cae01-4621-41f4-b768-c777cf94d1d8
# 1    PL.PZGIK.200  f322275e-1c48-431f-889e-8bb0ccb46e81
# 2    PL.PZGIK.200  59e7c5a7-8597-4c55-812a-b30932c08dd2
# 3    PL.PZGIK.200  e86b1e71-8958-42ee-bec5-ca3c87907bc8
# 4    PL.PZGIK.200  7f2af54d-150f-4b9f-b9fb-d2ce1b04166e
# ..            ...                                   ...
# 375  PL.PZGIK.200  82fd2232-f3be-487e-b7be-b6c27e9bed68
# 376  PL.PZGIK.200  1f87dd2e-136e-425b-a28e-fa7744058fb4
# 377  PL.PZGIK.200  024e370e-d84e-4487-a467-d184ee88816e
# 378  PL.PZGIK.200  a6773a99-a577-451d-9e24-a4b3e47ecf57
# 379  PL.PZGIK.200  387f7282-f74e-4cad-ac49-fab6a947a1fa
#
#                     iip_wersja jpt_sjr_ko jpt_kod_je  \
# 0    2012-09-27T08:01:01+02:00        POW       1812
# 1    2012-09-27T08:01:01+02:00        POW       1813
# 2    2012-09-27T08:01:01+02:00        POW       1814
# 3    2012-09-27T08:01:01+02:00        POW       1815
# 4    2012-09-27T08:01:01+02:00        POW       1816
# ..                         ...        ...        ...
# 375  2012-09-27T07:38:30+02:00        POW       0410
# 376  2012-09-27T07:38:30+02:00        POW       0412
# 377  2012-09-27T07:38:30+02:00        POW       0416
# 378  2012-09-27T07:38:30+02:00        POW       0404
# 379  2012-09-27T07:36:28+02:00        POW       0221
#
#                         jpt_nazwa_ jpt_nazw01 jpt_organ_ jpt_orga01  \
# 0                  powiat niżański       None       None        NZN
# 1                 powiat przemyski       None       None        NZN
# 2                powiat przeworski       None       None        NZN
# 3    powiat ropczycko-sędziszowski       None       None        NZN
# 4                powiat rzeszowski       None       None        NZN
# ..                             ...        ...        ...        ...
# 375               powiat nakielski       None       None        NZN
# 376                powiat rypiński       None       None        NZN
# 377               powiat tucholski       None       None        NZN
# 378              powiat chełmiński       None       None        NZN
# 379              powiat wałbrzyski       None       None        NZN
#
#      jpt_jor_id  ... id_bufor01 id_technic jpt_opis jpt_sps_ko gra_ids  \
# 0           NaN  ...    13878.0        NaN   829081        UZG    None
# 1           NaN  ...    13878.0        NaN   829082        UZG    None
# 2           NaN  ...    13878.0        NaN   829083        UZG    None
# 3           NaN  ...    13878.0        NaN   829084        UZG    None
# 4           NaN  ...    13878.0        NaN   829085        UZG    None
# ..          ...  ...        ...        ...      ...        ...     ...
# 375         NaN  ...    13889.0        NaN   829351        UZG    None
# 376         NaN  ...    13889.0        NaN   829352        UZG    None
# 377         NaN  ...    13889.0        NaN   829356        UZG    None
# 378         NaN  ...    13889.0        NaN   829364        UZG    None
# 379         NaN  ...    15071.0        NaN  1296647        UZG    None
#
#      status_obi opis_bledu typ_bledu  \
# 0      AKTUALNY       None      None
# 1      AKTUALNY       None      None
# 2      AKTUALNY       None      None
# 3      AKTUALNY       None      None
# 4      AKTUALNY       None      None
# ..          ...        ...       ...
# 375    AKTUALNY       None      None
# 376    AKTUALNY       None      None
# 377    AKTUALNY       None      None
# 378    AKTUALNY       None      None
# 379    AKTUALNY       None      None
#
#                                               geometry rozmiar_nat
# 0    MULTIPOLYGON (((711095.856 277431.597, 711101....   79.247132
# 1    MULTIPOLYGON (((734488.435 209795.384, 734490....  400.169741
# 2    MULTIPOLYGON (((731943.256 233158.050, 731989....   59.587417
# 3    MULTIPOLYGON (((676562.888 239118.997, 676567....    0.680983
# 4    MULTIPOLYGON (((696894.808 237348.347, 696909....   13.241718
# ..                                                 ...         ...
# 375  MULTIPOLYGON (((386094.901 571345.551, 386116....  150.110464
# 376  MULTIPOLYGON (((512068.791 574197.205, 512079....    1.242529
# 377  MULTIPOLYGON (((407425.341 632945.928, 407513....   39.484628
# 378  MULTIPOLYGON (((451113.176 597969.224, 451125....   29.222840
# 379  MULTIPOLYGON (((308068.348 335443.718, 308068....  226.177808
#
# [380 rows x 31 columns]

# %%
join.insert(2, "procent", (join['rozmiar_nat']/(join.area/1000000))*100)

# %%
join
# Out:
#        iip_przest                            iip_identy    procent  \
# 0    PL.PZGIK.200  f87cae01-4621-41f4-b768-c777cf94d1d8  10.088331
# 1    PL.PZGIK.200  f322275e-1c48-431f-889e-8bb0ccb46e81  33.029155
# 2    PL.PZGIK.200  59e7c5a7-8597-4c55-812a-b30932c08dd2   8.537366
# 3    PL.PZGIK.200  e86b1e71-8958-42ee-bec5-ca3c87907bc8   0.124262
# 4    PL.PZGIK.200  7f2af54d-150f-4b9f-b9fb-d2ce1b04166e   1.144354
# ..            ...                                   ...        ...
# 375  PL.PZGIK.200  82fd2232-f3be-487e-b7be-b6c27e9bed68  13.413002
# 376  PL.PZGIK.200  1f87dd2e-136e-425b-a28e-fa7744058fb4   0.212075
# 377  PL.PZGIK.200  024e370e-d84e-4487-a467-d184ee88816e   3.676452
# 378  PL.PZGIK.200  a6773a99-a577-451d-9e24-a4b3e47ecf57   5.552293
# 379  PL.PZGIK.200  387f7282-f74e-4cad-ac49-fab6a947a1fa  52.597838
#
#                     iip_wersja jpt_sjr_ko jpt_kod_je  \
# 0    2012-09-27T08:01:01+02:00        POW       1812
# 1    2012-09-27T08:01:01+02:00        POW       1813
# 2    2012-09-27T08:01:01+02:00        POW       1814
# 3    2012-09-27T08:01:01+02:00        POW       1815
# 4    2012-09-27T08:01:01+02:00        POW       1816
# ..                         ...        ...        ...
# 375  2012-09-27T07:38:30+02:00        POW       0410
# 376  2012-09-27T07:38:30+02:00        POW       0412
# 377  2012-09-27T07:38:30+02:00        POW       0416
# 378  2012-09-27T07:38:30+02:00        POW       0404
# 379  2012-09-27T07:36:28+02:00        POW       0221
#
#                         jpt_nazwa_ jpt_nazw01 jpt_organ_ jpt_orga01  ...  \
# 0                  powiat niżański       None       None        NZN  ...
# 1                 powiat przemyski       None       None        NZN  ...
# 2                powiat przeworski       None       None        NZN  ...
# 3    powiat ropczycko-sędziszowski       None       None        NZN  ...
# 4                powiat rzeszowski       None       None        NZN  ...
# ..                             ...        ...        ...        ...  ...
# 375               powiat nakielski       None       None        NZN  ...
# 376                powiat rypiński       None       None        NZN  ...
# 377               powiat tucholski       None       None        NZN  ...
# 378              powiat chełmiński       None       None        NZN  ...
# 379              powiat wałbrzyski       None       None        NZN  ...
#
#      id_bufor01 id_technic jpt_opis jpt_sps_ko gra_ids status_obi  opis_bledu  \
# 0       13878.0        NaN   829081        UZG    None   AKTUALNY        None
# 1       13878.0        NaN   829082        UZG    None   AKTUALNY        None
# 2       13878.0        NaN   829083        UZG    None   AKTUALNY        None
# 3       13878.0        NaN   829084        UZG    None   AKTUALNY        None
# 4       13878.0        NaN   829085        UZG    None   AKTUALNY        None
# ..          ...        ...      ...        ...     ...        ...         ...
# 375     13889.0        NaN   829351        UZG    None   AKTUALNY        None
# 376     13889.0        NaN   829352        UZG    None   AKTUALNY        None
# 377     13889.0        NaN   829356        UZG    None   AKTUALNY        None
# 378     13889.0        NaN   829364        UZG    None   AKTUALNY        None
# 379     15071.0        NaN  1296647        UZG    None   AKTUALNY        None
#
#     typ_bledu                                           geometry rozmiar_nat
# 0        None  MULTIPOLYGON (((711095.856 277431.597, 711101....   79.247132
# 1        None  MULTIPOLYGON (((734488.435 209795.384, 734490....  400.169741
# 2        None  MULTIPOLYGON (((731943.256 233158.050, 731989....   59.587417
# 3        None  MULTIPOLYGON (((676562.888 239118.997, 676567....    0.680983
# 4        None  MULTIPOLYGON (((696894.808 237348.347, 696909....   13.241718
# ..        ...                                                ...         ...
# 375      None  MULTIPOLYGON (((386094.901 571345.551, 386116....  150.110464
# 376      None  MULTIPOLYGON (((512068.791 574197.205, 512079....    1.242529
# 377      None  MULTIPOLYGON (((407425.341 632945.928, 407513....   39.484628
# 378      None  MULTIPOLYGON (((451113.176 597969.224, 451125....   29.222840
# 379      None  MULTIPOLYGON (((308068.348 335443.718, 308068....  226.177808
#
# [380 rows x 32 columns]

# %%
koniec = {'id_powiat': join['iip_identy'],'nazwa_powiatu': join['jpt_nazwa_'], 'powierzchnia_powiatu': join.area/1000000,'procent_powierzchni_zajmowany_przez_natura_2000': join['procent'],'geometry': join['geometry'],}

# %%
docsv = pd.DataFrame(data=koniec)

# %%
docsv
# Out:
#                                 id_powiat                  nazwa_powiatu  \
# 0    f87cae01-4621-41f4-b768-c777cf94d1d8                powiat niżański
# 1    f322275e-1c48-431f-889e-8bb0ccb46e81               powiat przemyski
# 2    59e7c5a7-8597-4c55-812a-b30932c08dd2              powiat przeworski
# 3    e86b1e71-8958-42ee-bec5-ca3c87907bc8  powiat ropczycko-sędziszowski
# 4    7f2af54d-150f-4b9f-b9fb-d2ce1b04166e              powiat rzeszowski
# ..                                    ...                            ...
# 375  82fd2232-f3be-487e-b7be-b6c27e9bed68               powiat nakielski
# 376  1f87dd2e-136e-425b-a28e-fa7744058fb4                powiat rypiński
# 377  024e370e-d84e-4487-a467-d184ee88816e               powiat tucholski
# 378  a6773a99-a577-451d-9e24-a4b3e47ecf57              powiat chełmiński
# 379  387f7282-f74e-4cad-ac49-fab6a947a1fa              powiat wałbrzyski
#
#      powierzchnia_powiatu  procent_powierzchni_zajmowany_przez_natura_2000  \
# 0              785.532651                                        10.088331
# 1             1211.565190                                        33.029155
# 2              697.960193                                         8.537366
# 3              548.023258                                         0.124262
# 4             1157.134339                                         1.144354
# ..                    ...                                              ...
# 375           1119.141475                                        13.413002
# 376            585.891454                                         0.212075
# 377           1073.987426                                         3.676452
# 378            526.320198                                         5.552293
# 379            430.013505                                        52.597838
#
#                                               geometry
# 0    MULTIPOLYGON (((711095.856 277431.597, 711101....
# 1    MULTIPOLYGON (((734488.435 209795.384, 734490....
# 2    MULTIPOLYGON (((731943.256 233158.050, 731989....
# 3    MULTIPOLYGON (((676562.888 239118.997, 676567....
# 4    MULTIPOLYGON (((696894.808 237348.347, 696909....
# ..                                                 ...
# 375  MULTIPOLYGON (((386094.901 571345.551, 386116....
# 376  MULTIPOLYGON (((512068.791 574197.205, 512079....
# 377  MULTIPOLYGON (((407425.341 632945.928, 407513....
# 378  MULTIPOLYGON (((451113.176 597969.224, 451125....
# 379  MULTIPOLYGON (((308068.348 335443.718, 308068....
#
# [380 rows x 5 columns]

# %%
styl = dict(method='zip',
                        archive_name='out.csv')
docsv.to_csv('out.zip',index=False,sep='|', compression=styl)
